# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt




plt.rc("font", size=14)
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import train_test_split

# %pylab inline
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# loading HPD violations filtered for 2014 
#https://nycopendata.socrata.com/Housing-Development/Housing-Maintenance-Code-Violations/wvxf-dwi5/data
# NYPD Complaints data hisrotric 
#https://data.cityofnewyork.us/Public-Safety/NYPD-Complaint-Data-Historic/qgea-i56i/data

viol = pd.read_csv('Housing_Maintenance_Code_Violations.csv')

# %%
viol.head(10)
# Out:
#    ViolationID  BuildingID  RegistrationID  BoroID   Borough HouseNumber  \
# 0     10392273      354043          818372       3  BROOKLYN        1757
# 1     10448977      116971          712919       2     BRONX        2039
# 2     10448978      116971          712919       2     BRONX        2039
# 3     10451389      116971          712919       2     BRONX        2039
# 4     10451447      116971          712919       2     BRONX        2039
# 5     10451474      116971          712919       2     BRONX        2039
# 6     10451477      116971          712919       2     BRONX        2039
# 7     10454776      138349          337388       3  BROOKLYN        5510
# 8     10485688       66501          712955       2     BRONX         500
# 9     10485693       66501          712955       2     BRONX         500
#
#   LowHouseNumber HighHouseNumber        StreetName  StreetCode  \
# 0           1757            1757     PITKIN AVENUE       70930
# ...

# %%
len(viol)
# Out:
# 397274

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
cities = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))

# %%
cities.head()
# Out:
#            name                                     geometry
# 0  Vatican City  POINT (12.45338654497177 41.90328217996012)
# 1    San Marino    POINT (12.44177015780014 43.936095834768)
# 2         Vaduz  POINT (9.516669472907267 47.13372377429357)
# 3    Luxembourg  POINT (6.130002806227083 49.61166037912108)
# 4       Palikir  POINT (158.1499743237623 6.916643696007725)

# %%
world.head()
# Out:
#       pop_est      continent                  name iso_a3  gdp_md_est  \
# 0  28400000.0           Asia           Afghanistan    AFG     22270.0
# 1  12799293.0         Africa                Angola    AGO    110300.0
# 2   3639453.0         Europe               Albania    ALB     21810.0
# 3   4798491.0           Asia  United Arab Emirates    ARE    184300.0
# 4  40913584.0  South America             Argentina    ARG    573900.0
#
#                                             geometry
# 0  POLYGON ((61.21081709172574 35.65007233330923,...
# 1  (POLYGON ((16.32652835456705 -5.87747039146621...
# 2  POLYGON ((20.59024743010491 41.85540416113361,...
# 3  POLYGON ((51.57951867046327 24.24549713795111,...
# 4  (POLYGON ((-65.50000000000003 -55.199999999999...

# %%
countries = world[['geometry', 'name']]

# %%
cities_with_country = gpd.sjoin(cities, countries, how="inner", op='intersects')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-19-9acf9a82ab64> in <module>()
# ----> 1 cities_with_country = gpd.sjoin(cities, countries, how="inner", op='intersects')
#
# /Users/avigailvantu/anaconda2/lib/python2.7/site-packages/geopandas/tools/sjoin.pyc in sjoin(left_df, right_df, how, op, lsuffix, rsuffix)
#      27
#      28     """
# ---> 29     import rtree
#      30
#      31     allowed_hows = ['left', 'right', 'inner']
#
# ImportError: No module named rtree
