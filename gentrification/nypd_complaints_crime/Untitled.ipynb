# %%
import pandas as pd
#import geopandas as gpd
import numpy as np

# %%
# this notebook aims to 
crime = pd.read_csv('NYPD_Complaint_Data_Historic.csv')

# %%
crime.head(50)
# Out:
#     CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0    228590732   01/01/2014     00:01:00          NaN          NaN
# 1    959301899   01/01/2014     12:00:00   05/16/2016     15:00:00
# 2    533545345   01/01/2014     09:00:00   12/07/2015     09:00:00
# 3    618456658   01/01/2014     00:00:00          NaN          NaN
# 4    252551348   01/01/2014     01:00:00   12/31/2014     23:59:00
# 5    637884754   01/01/2014     01:00:00   12/31/2014     23:59:00
# 6    746209814   01/01/2014     00:00:00   12/31/2014     00:00:00
# 7    740245503   01/01/2014     00:01:00   07/20/2016     23:59:00
# 8    929970427   01/01/2014     04:00:00   07/21/2016     23:00:00
# 9    350330424   01/01/2014     00:30:00   07/31/2015     23:00:00
# 10   642051167   01/01/2014     00:01:00          NaN          NaN
# 11   271021774   01/01/2014     18:00:00   08/07/2016     12:18:00
# 12   177012529   01/01/2014     00:01:00   06/10/2014     00:01:00
# ...

# %%
crime.columns
# Out:
# Index([u'CMPLNT_NUM', u'CMPLNT_FR_DT', u'CMPLNT_FR_TM', u'CMPLNT_TO_DT',
#        u'CMPLNT_TO_TM', u'RPT_DT', u'KY_CD', u'OFNS_DESC', u'PD_CD',
#        u'PD_DESC', u'CRM_ATPT_CPTD_CD', u'LAW_CAT_CD', u'JURIS_DESC',
#        u'BORO_NM', u'ADDR_PCT_CD', u'LOC_OF_OCCUR_DESC', u'PREM_TYP_DESC',
#        u'PARKS_NM', u'HADEVELOPT', u'X_COORD_CD', u'Y_COORD_CD', u'Latitude',
#        u'Longitude', u'Lat_Lon'],
#       dtype='object')

# %%
len(crime)
# Out:
# 491131

# %%
#filter only 2014
crime14 = crime[(crime['CMPLNT_FR_DT'] >'01/01/2014') & (crime['CMPLNT_FR_DT'] < '12/31/2014')]

# %%
len(crime14)
# Out:
# 487949

# %%
mis = crime14[(crime14['LAW_CAT_CD'] == 'MISDEMEANOR')]

# %%
fel = crime14[(crime14['LAW_CAT_CD'] == 'FELONY')]

# %%
dataf = [mis,fel]
mis_fel14 = pd.concat(dataf)

# %%
print len(mis_fel14)
print len(mis)
print len(fel)
# Out:
# 425342
# 275158
# 150184

# %%
viol = crime14[(crime14['LAW_CAT_CD'] == 'VIOLATION')]

# %%
viol.to_csv('crime_viol.csv')
mis_fel14.to_csv('crime_mis_fel.csv')

# %%
#crime['LAW_CAT_CD']
