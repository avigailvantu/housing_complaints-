# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt 
plt.rc("font", size=14)
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import train_test_split

# %pylab inline
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/avigailvantu/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# the goal of this anylsis is to come up with an NYC city level description of housing condition.
# this will be made taking into account only OCCUPIED units and by including controlled + stabilized + un regulated housing conditions.
#
# this is the dirst type of data in th "housing funnel""
#
# (hvs nyc -> hpd complaints -> hpd violations -> court data)
#
# hvs nyc analysis purpose:
# 1. only analyze the most recent data - 2014
# 2. use the excel version
# 3. look for variables who appear on the Springer report as well as those appearing in the housing complaints and violations data
#
# intermidate goales:
#
# 1. Bronx and Brooklyn comparison
# 2.
#
# Variables from HVS NYC:
#
# - Broken Plaster or Peeling Paint Heating Equipment Breakdown
# - Carbon Monoxide Detector.
# - Complete Kitchen Facilities
# - Complete Plumbing Facilities
# - Condition of Building (Observation).
# - Condition of External Walls
# - Condition of Floors
# - Condition of Stairways (Exterior and Interior).
# - Condition of Building Recode
# - Condition of Windows
# - Cracks or Holes in Interior Walls or Ceiling
# - Heating Equipment Breakdown
# - Musty/Moldy Smells
# - Number of Cockroaches
# - *unfound* - Presence of Mice and Rats
# - Water Leakage Inside Apartment
#
# file:///Users/avigailvantu/Downloads/toc.pdf![image.png](attachment:image.png)
#
# Data can be accessed here:
#
# https://www.census.gov/data/tables/time-series/demo/nychvs/series-1b.html

# %%
External_Walls = pd.read_csv('Broken Plaster.csv')
#prob = pd.read_csv('Complaint_Problems.csv')
#bbl = pd.read_csv('pluto.csv')
#pop_b = pd.read_csv('NYC_Population_by_Borough.csv')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-5-45d431498e6b> in <module>()
# ----> 1 External_Walls = pd.read_csv('Broken Plaster.csv')
#       2 #prob = pd.read_csv('Complaint_Problems.csv')
#       3 #bbl = pd.read_csv('pluto.csv')
#       4 #pop_b = pd.read_csv('NYC_Population_by_Borough.csv')
#
# ...

# %%
cd
